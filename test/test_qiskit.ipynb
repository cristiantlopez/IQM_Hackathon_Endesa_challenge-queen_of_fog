# %% [markdown]
# # Hybrid quantum-classical battery arbitrage (QUBO + classical repair)
# We keep the physical limits and price-driven objective from the MILP and push only the binary on/off charging decisions to a QUBO that can be sampled with QAOA/annealing. Continuous pieces (state of charge, feasibility repairs, and final scoring) stay classical.

# %% [markdown]
# ## Problem recap
# - 24 hourly prices \(p_{t}\); wind revenue is a constant.
# - Battery: \(E^{\max}=16\) MWh, \(P^{\max}_{ch}=5\) MW, \(P^{\max}_{dis}=4\) MW, \(\eta_{ch}=0.8\), \(\eta_{dis}=1.0\), start/end SOC = 0.
# - Cycle budget proxy: \(\sum_{t} d_{t} \le 32\) MWh (\(\le 2\) equivalent full discharges).
# - Binary actions per hour: charge (`c_t`), discharge (`d_t`), or idle (`i_t`). We fix power at the limits (5/4 MW) so SOC is a deterministic linear function of the action string.\
# This makes the model binary-only with linear constraints; it can be converted automatically to a QUBO.

# %%
import pandas as pd
from pathlib import Path

# Load price data
# Works whether run from repo root or test/
data_path = Path('input_data.csv')
if not data_path.exists():
    data_path = Path.cwd().parent / 'input_data.csv'

df = pd.read_csv(data_path)
hours = df['hour'].astype(int).tolist()
prices = df.set_index('hour')['price'].to_dict()

# Parameters (same as MILP)
Pch = 5.0
Pdis = 4.0
Emax = 16.0
eta_ch = 0.8
eta_dis = 1.0
max_cycles = 2  # EFC proxy

# %% [markdown]
# ## Hybrid design
# 1) **Binary schedule as QUBO**: use two binaries per hour (`charge_t`, `dis_t`) with constraint `charge_t + dis_t <= 1`. Power is fixed at the limits.\
# 2) **Linear SOC constraints stay classical**: cumulative SOC after hour t is \(\sum_{\tau \le t} (\eta_{ch} P_{ch} c_{\tau} - P_{dis}/\eta_{dis} \; d_{\tau})\). We impose 0 <= SOC <= Emax for every t and SOC_{24}=0 as linear constraints. Cycle budget is another linear inequality.\
# 3) **Convert to QUBO**: the binary linear program is converted with penalty terms (Qiskit `QuadraticProgramToQubo`). The objective is price arbitrage \(\sum_{t} p_{t}(P_{dis} d_{t} - P_{ch} c_{t})\).\
# 4) **Quantum sampler**: solve the QUBO with QAOA/annealing to get candidate bitstrings.\
# 5) **Classical repair & scoring**: map bitstrings to SOC trajectory, drop infeasible ones, optionally greedily fix a few hours, and evaluate objective exactly. Use MILP as a verifier/benchmark if desired.

# %%
from qiskit_optimization import QuadraticProgram
from qiskit_optimization.converters import QuadraticProgramToQubo

# Optional solvers (commented to avoid execution if not installed)
from qiskit_algorithms import QAOA
from qiskit_algorithms.optimizers import COBYLA
from qiskit_optimization.algorithms import MinimumEigenOptimizer
#from qiskit.primitives import Sampler

def build_arbitrage_qp(prices, hours, *, Pch, Pdis, Emax, eta_ch, eta_dis, max_cycles):
    qp = QuadraticProgram(name='battery_arbitrage_qubo_ready')
    # Decision binaries and exclusivity
    for t in hours:
        qp.binary_var(name=f'charge_{t}')
        qp.binary_var(name=f'dis_{t}')
        qp.linear_constraint(linear={f'charge_{t}': 1, f'dis_{t}': 1}, sense='<=', rhs=1, name=f'mode_limit_{t}')

    # SOC running-sum constraints (prefix sums, all linear)
    for t in hours:
        coeffs = {}
        for tau in hours:
            if tau <= t:
                coeffs[f'charge_{tau}'] = coeffs.get(f'charge_{tau}', 0.0) + eta_ch * Pch
                coeffs[f'dis_{tau}'] = coeffs.get(f'dis_{tau}', 0.0) - Pdis / eta_dis
        qp.linear_constraint(linear=coeffs, sense='<=', rhs=Emax, name=f'soc_max_{t}')
        qp.linear_constraint(linear=coeffs, sense='>=', rhs=0.0, name=f'soc_min_{t}')

    # Terminal SOC = 0
    coeffs_terminal = {}
    for tau in hours:
        coeffs_terminal[f'charge_{tau}'] = coeffs_terminal.get(f'charge_{tau}', 0.0) + eta_ch * Pch
        coeffs_terminal[f'dis_{tau}'] = coeffs_terminal.get(f'dis_{tau}', 0.0) - Pdis / eta_dis
    qp.linear_constraint(linear=coeffs_terminal, sense='==', rhs=0.0, name='soc_end_zero')

    # Cycle/EFC budget
    qp.linear_constraint(linear={f'dis_{t}': Pdis for t in hours}, sense='<=', rhs=max_cycles * Emax, name='cycle_budget')

    # Objective: price-weighted arbitrage (maximize)
    linear_obj = {f'dis_{t}': prices[t] * Pdis for t in hours}
    linear_obj.update({f'charge_{t}': -prices[t] * Pch for t in hours})
    qp.maximize(linear=linear_obj)
    return qp

qp = build_arbitrage_qp(prices, hours, Pch=Pch, Pdis=Pdis, Emax=Emax, eta_ch=eta_ch, eta_dis=eta_dis, max_cycles=max_cycles)
print(qp.prettyprint())

# Convert to QUBO (penalty can be tuned; leave None for automatic choice)
converter = QuadraticProgramToQubo(penalty=None)
qubo = converter.convert(qp)
print(qubo)

# Example solver wiring (commented out to avoid execution):
# sampler = Sampler()
# qaoa = QAOA(sampler=sampler, reps=2, optimizer=COBYLA(maxiter=50))
# meo = MinimumEigenOptimizer(qaoa)
# result = meo.solve(qubo)
# print('Best candidate objective:', result.fval)
# print(result.variables_dict)
# Out:
# Problem name: battery_arbitrage_qubo_ready
#
# Maximize
#   -444.79999999999995*charge_1 - 354.45*charge_10 - 170.7*charge_11
#   - 99.85*charge_12 - 82.44999999999999*charge_13 - 68.60000000000001*charge_14
#   - 93.10000000000001*charge_15 - 168.25*charge_16 - 315*charge_17
#   - 551.85*charge_18 - 625.15*charge_19 - 419.09999999999997*charge_2
#   - 738*charge_20 - 757.0999999999999*charge_21 - 652.45*charge_22
#   - 511.4*charge_23 - 459.25*charge_24 - 415*charge_3 - 412.8*charge_4
#   - 414.09999999999997*charge_5 - 430.05*charge_6 - 516.05*charge_7
#   - 665.45*charge_8 - 568.65*charge_9 + 355.84*dis_1 + 283.56*dis_10
#   + 136.56*dis_11 + 79.88*dis_12 + 65.96*dis_13 + 54.88*dis_14 + 74.48*dis_15
#   + 134.6*dis_16 + 252*dis_17 + 441.48*dis_18 + 500.12*dis_19 + 335.28*dis_2
#   + 590.4*dis_20 + 605.68*dis_21 + 521.96*dis_22 + 409.12*dis_23 + 367.4*dis_24
#   + 332*dis_3 + 330.24*dis_4 + 331.28*dis_5 + 344.04*dis_6 + 412.84*dis_7
#   + 532.36*dis_8 + 454.92*dis_9
#
# Subject to
#   Linear constraints (74)
#     charge_1 + dis_1 <= 1  'mode_limit_1'
#     charge_2 + dis_2 <= 1  'mode_limit_2'
#     charge_3 + dis_3 <= 1  'mode_limit_3'
#     charge_4 + dis_4 <= 1  'mode_limit_4'
#     charge_5 + dis_5 <= 1  'mode_limit_5'
#     charge_6 + dis_6 <= 1  'mode_limit_6'
#     charge_7 + dis_7 <= 1  'mode_limit_7'
#     charge_8 + dis_8 <= 1  'mode_limit_8'
#     charge_9 + dis_9 <= 1  'mode_limit_9'
#     charge_10 + dis_10 <= 1  'mode_limit_10'
#     charge_11 + dis_11 <= 1  'mode_limit_11'
#     charge_12 + dis_12 <= 1  'mode_limit_12'
#     charge_13 + dis_13 <= 1  'mode_limit_13'
#     charge_14 + dis_14 <= 1  'mode_limit_14'
#     charge_15 + dis_15 <= 1  'mode_limit_15'
#     charge_16 + dis_16 <= 1  'mode_limit_16'
#     charge_17 + dis_17 <= 1  'mode_limit_17'
#     charge_18 + dis_18 <= 1  'mode_limit_18'
#     charge_19 + dis_19 <= 1  'mode_limit_19'
#     charge_20 + dis_20 <= 1  'mode_limit_20'
#     charge_21 + dis_21 <= 1  'mode_limit_21'
#     charge_22 + dis_22 <= 1  'mode_limit_22'
#     charge_23 + dis_23 <= 1  'mode_limit_23'
#     charge_24 + dis_24 <= 1  'mode_limit_24'
#     4*charge_1 - 4*dis_1 <= 16  'soc_max_1'
#     4*charge_1 - 4*dis_1 >= 0  'soc_min_1'
#     4*charge_1 + 4*charge_2 - 4*dis_1 - 4*dis_2 <= 16  'soc_max_2'
#     4*charge_1 + 4*charge_2 - 4*dis_1 - 4*dis_2 >= 0  'soc_min_2'
#     4*charge_1 + 4*charge_2 + 4*charge_3 - 4*dis_1 - 4*dis_2 - 4*dis_3
#     <= 16  'soc_max_3'
#     4*charge_1 + 4*charge_2 + 4*charge_3 - 4*dis_1 - 4*dis_2 - 4*dis_3
#     >= 0  'soc_min_3'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 - 4*dis_1 - 4*dis_2
#     - 4*dis_3 - 4*dis_4 <= 16  'soc_max_4'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 - 4*dis_1 - 4*dis_2
#     - 4*dis_3 - 4*dis_4 >= 0  'soc_min_4'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 - 4*dis_1
#     - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 <= 16  'soc_max_5'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 - 4*dis_1
#     - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 >= 0  'soc_min_5'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     - 4*dis_1 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6
#     <= 16  'soc_max_6'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     - 4*dis_1 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6
#     >= 0  'soc_min_6'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 - 4*dis_1 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6
#     - 4*dis_7 <= 16  'soc_max_7'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 - 4*dis_1 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6
#     - 4*dis_7 >= 0  'soc_min_7'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 - 4*dis_1 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5
#     - 4*dis_6 - 4*dis_7 - 4*dis_8 <= 16  'soc_max_8'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 - 4*dis_1 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5
#     - 4*dis_6 - 4*dis_7 - 4*dis_8 >= 0  'soc_min_8'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_2 - 4*dis_3
#     - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9
#     <= 16  'soc_max_9'
#     4*charge_1 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_2 - 4*dis_3
#     - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9
#     >= 0  'soc_min_9'
#     4*charge_1 + 4*charge_10 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 <= 16  'soc_max_10'
#     4*charge_1 + 4*charge_10 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 >= 0  'soc_min_10'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_2 + 4*charge_3
#     + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8
#     + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_2 - 4*dis_3 - 4*dis_4
#     - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 <= 16  'soc_max_11'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_2 + 4*charge_3
#     + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8
#     + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_2 - 4*dis_3 - 4*dis_4
#     - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 >= 0  'soc_min_11'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_2
#     + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7
#     + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12
#     - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 <= 16  'soc_max_12'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_2
#     + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7
#     + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12
#     - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 >= 0  'soc_min_12'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11
#     - 4*dis_12 - 4*dis_13 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6
#     - 4*dis_7 - 4*dis_8 - 4*dis_9 <= 16  'soc_max_13'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11
#     - 4*dis_12 - 4*dis_13 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6
#     - 4*dis_7 - 4*dis_8 - 4*dis_9 >= 0  'soc_min_13'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_2 - 4*dis_3 - 4*dis_4
#     - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 <= 16  'soc_max_14'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_2 - 4*dis_3 - 4*dis_4
#     - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 >= 0  'soc_min_14'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_2 + 4*charge_3 + 4*charge_4
#     + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1
#     - 4*dis_10 - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_2
#     - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9
#     <= 16  'soc_max_15'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_2 + 4*charge_3 + 4*charge_4
#     + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1
#     - 4*dis_10 - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_2
#     - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9
#     >= 0  'soc_min_15'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_2 + 4*charge_3
#     + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8
#     + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12 - 4*dis_13
#     - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5
#     - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 <= 16  'soc_max_16'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_2 + 4*charge_3
#     + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8
#     + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12 - 4*dis_13
#     - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5
#     - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 >= 0  'soc_min_16'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_2
#     + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7
#     + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12
#     - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_2 - 4*dis_3
#     - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9
#     <= 16  'soc_max_17'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_2
#     + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7
#     + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12
#     - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_2 - 4*dis_3
#     - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9
#     >= 0  'soc_min_17'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11
#     - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_18
#     - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 <= 16  'soc_max_18'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11
#     - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_18
#     - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 >= 0  'soc_min_18'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17
#     - 4*dis_18 - 4*dis_19 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6
#     - 4*dis_7 - 4*dis_8 - 4*dis_9 <= 16  'soc_max_19'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17
#     - 4*dis_18 - 4*dis_19 - 4*dis_2 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6
#     - 4*dis_7 - 4*dis_8 - 4*dis_9 >= 0  'soc_min_19'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_3 + 4*charge_4
#     + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1
#     - 4*dis_10 - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16
#     - 4*dis_17 - 4*dis_18 - 4*dis_19 - 4*dis_2 - 4*dis_20 - 4*dis_3 - 4*dis_4
#     - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 <= 16  'soc_max_20'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_3 + 4*charge_4
#     + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1
#     - 4*dis_10 - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16
#     - 4*dis_17 - 4*dis_18 - 4*dis_19 - 4*dis_2 - 4*dis_20 - 4*dis_3 - 4*dis_4
#     - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 >= 0  'soc_min_20'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_3
#     + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8
#     + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12 - 4*dis_13
#     - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_18 - 4*dis_19 - 4*dis_2
#     - 4*dis_20 - 4*dis_21 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7
#     - 4*dis_8 - 4*dis_9 <= 16  'soc_max_21'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_3
#     + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7 + 4*charge_8
#     + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12 - 4*dis_13
#     - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_18 - 4*dis_19 - 4*dis_2
#     - 4*dis_20 - 4*dis_21 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7
#     - 4*dis_8 - 4*dis_9 >= 0  'soc_min_21'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_22
#     + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7
#     + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12
#     - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_18 - 4*dis_19
#     - 4*dis_2 - 4*dis_20 - 4*dis_21 - 4*dis_22 - 4*dis_3 - 4*dis_4 - 4*dis_5
#     - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 <= 16  'soc_max_22'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_22
#     + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6 + 4*charge_7
#     + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11 - 4*dis_12
#     - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_18 - 4*dis_19
#     - 4*dis_2 - 4*dis_20 - 4*dis_21 - 4*dis_22 - 4*dis_3 - 4*dis_4 - 4*dis_5
#     - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9 >= 0  'soc_min_22'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_22
#     + 4*charge_23 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11
#     - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_18
#     - 4*dis_19 - 4*dis_2 - 4*dis_20 - 4*dis_21 - 4*dis_22 - 4*dis_23 - 4*dis_3
#     - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9
#     <= 16  'soc_max_23'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_22
#     + 4*charge_23 + 4*charge_3 + 4*charge_4 + 4*charge_5 + 4*charge_6
#     + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10 - 4*dis_11
#     - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17 - 4*dis_18
#     - 4*dis_19 - 4*dis_2 - 4*dis_20 - 4*dis_21 - 4*dis_22 - 4*dis_23 - 4*dis_3
#     - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8 - 4*dis_9
#     >= 0  'soc_min_23'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_22
#     + 4*charge_23 + 4*charge_24 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17
#     - 4*dis_18 - 4*dis_19 - 4*dis_2 - 4*dis_20 - 4*dis_21 - 4*dis_22 - 4*dis_23
#     - 4*dis_24 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 <= 16  'soc_max_24'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_22
#     + 4*charge_23 + 4*charge_24 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17
#     - 4*dis_18 - 4*dis_19 - 4*dis_2 - 4*dis_20 - 4*dis_21 - 4*dis_22 - 4*dis_23
#     - 4*dis_24 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 >= 0  'soc_min_24'
#     4*charge_1 + 4*charge_10 + 4*charge_11 + 4*charge_12 + 4*charge_13
#     + 4*charge_14 + 4*charge_15 + 4*charge_16 + 4*charge_17 + 4*charge_18
#     + 4*charge_19 + 4*charge_2 + 4*charge_20 + 4*charge_21 + 4*charge_22
#     + 4*charge_23 + 4*charge_24 + 4*charge_3 + 4*charge_4 + 4*charge_5
#     + 4*charge_6 + 4*charge_7 + 4*charge_8 + 4*charge_9 - 4*dis_1 - 4*dis_10
#     - 4*dis_11 - 4*dis_12 - 4*dis_13 - 4*dis_14 - 4*dis_15 - 4*dis_16 - 4*dis_17
#     - 4*dis_18 - 4*dis_19 - 4*dis_2 - 4*dis_20 - 4*dis_21 - 4*dis_22 - 4*dis_23
#     - 4*dis_24 - 4*dis_3 - 4*dis_4 - 4*dis_5 - 4*dis_6 - 4*dis_7 - 4*dis_8
#     - 4*dis_9 == 0  'soc_end_zero'
#     4*dis_1 + 4*dis_10 + 4*dis_11 + 4*dis_12 + 4*dis_13 + 4*dis_14 + 4*dis_15
#     + 4*dis_16 + 4*dis_17 + 4*dis_18 + 4*dis_19 + 4*dis_2 + 4*dis_20 + 4*dis_21
#     + 4*dis_22 + 4*dis_23 + 4*dis_24 + 4*dis_3 + 4*dis_4 + 4*dis_5 + 4*dis_6
#     + 4*dis_7 + 4*dis_8 + 4*dis_9 <= 32  'cycle_budget'
#
#   Binary variables (48)
#     charge_1 dis_1 charge_2 dis_2 charge_3 dis_3 charge_4 dis_4 charge_5 dis_5
#     charge_6 dis_6 charge_7 dis_7 charge_8 dis_8 charge_9 dis_9 charge_10 dis_10
#     charge_11 dis_11 charge_12 dis_12 charge_13 dis_13 charge_14 dis_14
#     charge_15 dis_15 charge_16 dis_16 charge_17 dis_17 charge_18 dis_18
#     charge_19 dis_19 charge_20 dis_20 charge_21 dis_21 charge_22 dis_22
#     charge_23 dis_23 charge_24 dis_24
#
# minimize 350477007.99999994*charge_1^2 + 443460703.99999994*charge_1*charge_10 + 414850335.99999994*charge_1*charge_11 + 386239967.99999994*charge_1*charge_12 + 357629599.99999994*charge_1*charge_13 + 329019231.99999994*charge_1*charge_14 + 300408863.99999994*charge_1*charge_15 + 271798495.99999994*charge_1*charge_16 + 243188127.99999997*charge_1*charge_17 + 214577759.99999997*charge_1*charge_18 + 185967391.99999997*charge_1*charge_19 + 672343647.9999999*charge_1*charge_2 + 157357023.99999997*charge_1*charge_20 + 128746655.99999999*charge_1*charge_21 + 100136287.99999999*charge_1*charge_22 + 71525919.99999999*charge_1*charge_23 + 42915551.999999985*charge_1*charge_24 + 643733279.9999999*charge_1*charge_3 + 615122911.9999999*charge_1*charge_4 + 586512543.9999999*charge_1*charge_5 + 557902175.9999999*charge_1*charge_6 + 529291807.99999994*charge_1*charge_7 + 500681439.99999994*charge_1*charge_8 + 472071071.99999994*charge_1*charge_9 - 700936134.52*charge_1*dis_1 - 443460703.99999994*charge_1*dis_10 - 414850335.99999994*charge_1*dis_11 - 386239967.99999994*charge_1*dis_12 - 357629599.99999994*charge_1*dis_13 - 329019231.99999994*charge_1*dis_14 - 300408863.99999994*charge_1*dis_15 - 271798495.99999994*charge_1*dis_16 - 243188127.99999997*charge_1*dis_17 - 214577759.99999997*charge_1*dis_18 - 185967391.99999997*charge_1*dis_19 - 672343647.9999999*charge_1*dis_2 - 157357023.99999997*charge_1*dis_20 - 128746655.99999999*charge_1*dis_21 - 100136287.99999999*charge_1*dis_22 - 71525919.99999999*charge_1*dis_23 - 42915551.999999985*charge_1*dis_24 - 643733279.9999999*charge_1*dis_3 - 615122911.9999999*charge_1*dis_4 - 586512543.9999999*charge_1*dis_5 - 557902175.9999999*charge_1*dis_6 - 529291807.99999994*charge_1*dis_7 - 500681439.99999994*charge_1*dis_8 - 472071071.99999994*charge_1*dis_9 + 3576295.999999999*charge_1*soc_max_10@int_slack@0 + 7152591.999999998*charge_1*soc_max_10@int_slack@1 + 14305183.999999996*charge_1*soc_max_10@int_slack@2 + 28610367.999999993*charge_1*soc_max_10@int_slack@3 + 57220735.999999985*charge_1*soc_max_10@int_slack@4 + 89407399.99999997*charge_1*soc_max_10@int_slack@5 + 3576295.999999999*charge_1*soc_max_11@int_slack@0 + 7152591.999999998*charge_1*soc_max_11@int_slack@1 + 14305183.999999996*charge_1*soc_max_11@int_slack@2 + 28610367.999999993*charge_1*soc_max_11@int_slack@3 + 57220735.999999985*charge_1*soc_max_11@int_slack@4 + 103712583.99999997*charge_1*soc_max_11@int_slack@5 + 3576295.999999999*charge_1*soc_max_12@int_slack@0 + 7152591.999999998*charge_1*soc_max_12@int_slack@1 + 14305183.999999996*charge_1*soc_max_12@int_slack@2 + 28610367.999999993*charge_1*soc_max_12@int_slack@3 + 57220735.999999985*charge_1*soc_max_12@int_slack@4 + 114441471.99999997*charge_1*soc_max_12@int_slack@5 + 3576295.999999999*charge_1*soc_max_12@int_slack@6 + 3576295.999999999*charge_1*soc_max_13@int_slack@0 + 7152591.999999998*charge_1*soc_max_13@int_slack@1 + 14305183.999999996*charge_1*soc_max_13@int_slack@2 + 28610367.999999993*charge_1*soc_max_13@int_slack@3 + 57220735.999999985*charge_1*soc_max_13@int_slack@4 + 114441471.99999997*charge_1*soc_max_13@int_slack@5 + 17881479.999999996*charge_1*soc_max_13@int_slack@6 + 3576295.999999999*charge_1*soc_max_14@int_slack@0 + 7152591.999999998*charge_1*soc_max_14@int_slack@1 + 14305183.999999996*charge_1*soc_max_14@int_slack@2 + 28610367.999999993*charge_1*soc_max_14@int_slack@3 + 57220735.999999985*charge_1*soc_max_14@int_slack@4 + 114441471.99999997*charge_1*soc_max_14@int_slack@5 + 32186663.999999993*charge_1*soc_max_14@int_slack@6 + 3576295.999999999*charge_1*soc_max_15@int_slack@0 + 7152591.999999998*charge_1*soc_max_15@int_slack@1 + 14305183.999999996*charge_1*soc_max_15@int_slack@2 + 28610367.999999993*charge_1*soc_max_15@int_slack@3 + 57220735.999999985*charge_1*soc_max_15@int_slack@4 + 114441471.99999997*charge_1*soc_max_15@int_slack@5 + 46491847.999999985*charge_1*soc_max_15@int_slack@6 + 3576295.999999999*charge_1*soc_max_16@int_slack@0 + 7152591.999999998*charge_1*s ...

# %%
print("QUBO binaries =", len(qubo.variables))
# Out:
# QUBO binaries = 350

# %%
"""
QAOA for the simplest discrete skeleton:
- exactly ONE full 4h charge block at max power (5 MWh/h)
- exactly ONE full 4h discharge block at max power (4 MWh/h)
- discharge must start AFTER charge finishes (j >= i+4)

Decision variables (one-hot):
  u_i = 1  if charge block starts at hour i  (i = 1..21)
  v_j = 1  if discharge block starts at hour j (j = 1..21)

Objective (maximize profit) turned into QUBO minimization:
  min  sum_i C_i u_i  - sum_j R_j v_j
      + A( sum_i u_i - 1 )^2
      + A( sum_j v_j - 1 )^2
      + B * sum_{i} sum_{j < i+4} u_i v_j

Requires:
  pip install qiskit qiskit-algorithms qiskit-optimization pandas numpy
"""

import numpy as np
import pandas as pd

from qiskit.primitives import StatevectorSampler as Sampler
from qiskit_algorithms import QAOA
from qiskit_algorithms.optimizers import COBYLA
from qiskit_optimization import QuadraticProgram
from qiskit_optimization.algorithms import MinimumEigenOptimizer


def build_qubo_from_prices(prices: np.ndarray, A: float | None = None, B: float | None = None):
    """
    Build a pure QUBO QuadraticProgram for the single full-cycle skeleton.
    prices: length-24 array, p_t in EUR/MWh for t=1..24
    """
    assert len(prices) == 24
    # feasible start times for a 4-hour block: 1..21
    starts = np.arange(1, 22)  # 1..21
    n = len(starts)

    # Precompute block costs/revenues
    # Charge cost if start i: C_i = 5 * sum_{t=i..i+3} p_t
    # Discharge revenue if start j: R_j = 4 * sum_{t=j..j+3} p_t
    C = np.array([5.0 * prices[i - 1 : i - 1 + 4].sum() for i in starts])
    R = np.array([4.0 * prices[j - 1 : j - 1 + 4].sum() for j in starts])

    # Choose penalty magnitudes if not provided
    scale = float(max(C.max(), R.max()))
    if A is None:
        A = 10.0 * scale  # strong enough to enforce one-hot
    if B is None:
        B = 10.0 * scale  # strong enough to enforce ordering

    qp = QuadraticProgram("battery_single_cycle_skeleton")

    # Variables: u_1..u_21, v_1..v_21
    u_names = [f"u_{i}" for i in starts]
    v_names = [f"v_{j}" for j in starts]
    for name in u_names + v_names:
        qp.binary_var(name)

    linear = {}
    quadratic = {}
    constant = 0.0

    def add_linear(var, coeff):
        linear[var] = linear.get(var, 0.0) + float(coeff)

    def add_quadratic(var1, var2, coeff):
        # Canonicalize key ordering for consistency
        a, b = (var1, var2) if var1 <= var2 else (var2, var1)
        quadratic[(a, b)] = quadratic.get((a, b), 0.0) + float(coeff)

    # Economic term: min sum C_i u_i - sum R_j v_j
    for k, i in enumerate(starts):
        add_linear(f"u_{i}", C[k])
    for k, j in enumerate(starts):
        add_linear(f"v_{j}", -R[k])

    # One-hot penalty for u: A( sum u - 1 )^2
    # Expands to: A( -sum u + 2*sum_{i<k} u_i u_k + 1 )
    constant += A
    for i in starts:
        add_linear(f"u_{i}", -A)
    for a in range(n):
        for b in range(a + 1, n):
            add_quadratic(f"u_{starts[a]}", f"u_{starts[b]}", 2.0 * A)

    # One-hot penalty for v: A( sum v - 1 )^2
    constant += A
    for j in starts:
        add_linear(f"v_{j}", -A)
    for a in range(n):
        for b in range(a + 1, n):
            add_quadratic(f"v_{starts[a]}", f"v_{starts[b]}", 2.0 * A)

    # Ordering penalty: forbid discharge starting before charge finishes
    # If charge starts at i, charge occupies i..i+3, so discharge must start at j >= i+4.
    # Penalize illegal pairs (j < i+4):  B * u_i * v_j
    for i in starts:
        for j in starts:
            if j < i + 4:
                add_quadratic(f"u_{i}", f"v_{j}", B)

    qp.minimize(constant=constant, linear=linear, quadratic=quadratic)

    return qp, starts, C, R, A, B


def decode_solution(result, starts):
    """Extract chosen (i,j) from the optimizer result."""
    x = result.x  # solution vector in the order qp.variables
    var_names = [v.name for v in result.variables]
    sol = dict(zip(var_names, x))

    # pick argmax among u_i and v_j (should be exactly 1 if penalties worked)
    u_vals = np.array([sol[f"u_{i}"] for i in starts])
    v_vals = np.array([sol[f"v_{j}"] for j in starts])

    i_star = int(starts[u_vals.argmax()])
    j_star = int(starts[v_vals.argmax()])
    return i_star, j_star, sol


def main():
    data_path = Path('input_data.csv')
    if not data_path.exists():
        data_path = Path.cwd().parent / 'input_data.csv'
    df = pd.read_csv(data_path)

    prices = df["price"].to_numpy()

    qp, starts, C, R, A, B = build_qubo_from_prices(prices, A=None, B=None)

    # QAOA setup (statevector simulation)
    sampler = Sampler(default_shots=4096)
    optimizer = COBYLA(maxiter=250)
    qaoa = QAOA(sampler=sampler, optimizer=optimizer, reps=2)

    # Solve QUBO with QAOA
    meo = MinimumEigenOptimizer(qaoa)
    result = meo.solve(qp)

    i_star, j_star, sol = decode_solution(result, starts)

    # Compute profit of the decoded schedule (in EUR)
    # profit = discharge revenue - charge cost
    Ci = 5.0 * prices[i_star - 1 : i_star - 1 + 4].sum()
    Rj = 4.0 * prices[j_star - 1 : j_star - 1 + 4].sum()
    profit = Rj - Ci

    print("=== QAOA result (single full cycle skeleton) ===")
    print(f"Chosen charge start i* = {i_star}  (hours {i_star}-{i_star+3})")
    print(f"Chosen discharge start j* = {j_star} (hours {j_star}-{j_star+3})")
    print(f"Profit (EUR) = {profit:.2f}")
    print(f"Penalty weights: A={A:.1f}, B={B:.1f}")
    print()

    # Optional: quick classical verification (brute force over feasible pairs)
    best = (-1e18, None, None)
    for i in starts:
        for j in starts:
            if j >= i + 4:
                Ci = 5.0 * prices[i - 1 : i - 1 + 4].sum()
                Rj = 4.0 * prices[j - 1 : j - 1 + 4].sum()
                pr = Rj - Ci
                if pr > best[0]:
                    best = (pr, i, j)
    print("=== Classical check (brute force) ===")
    print(f"Best feasible profit (EUR) = {best[0]:.2f} at i={best[1]}, j={best[2]}")

    # Build a readable 24h schedule for the decoded (i*,j*) plan
    schedule = []
    for t in range(1, 25):
        if i_star <= t <= i_star + 3:
            schedule.append(("CH", 5.0, 0.0))
        elif j_star <= t <= j_star + 3:
            schedule.append(("DIS", 0.0, 4.0))
        else:
            schedule.append(("IDLE", 0.0, 0.0))

    out = pd.DataFrame({
        "hour": np.arange(1, 25),
        "price": prices,
        "mode": [m for (m, _, _) in schedule],
        "charge_MWh": [c for (_, c, _) in schedule],
        "discharge_MWh": [d for (_, _, d) in schedule],
    })
    print("\n=== 24h schedule (decoded) ===")
    print(out.to_string(index=False))


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[11], line 194
#     190     print(out.to_string(index=False))
#     193 if __name__ == "__main__":
# --> 194     main()
#
# Cell In[11], line 142, in main()
#     140 # Solve QUBO with QAOA
#     141 meo = MinimumEigenOptimizer(qaoa)
# --> 142 result = meo.solve(qp)
#     144 i_star, j_star, sol = decode_solution(result, starts)
#     146 # Compute profit of the decoded schedule (in EUR)
#     147 # profit = discharge revenue - charge cost
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit_optimization\algorithms\minimum_eigen_optimizer.py:204, in MinimumEigenOptimizer.solve(self, problem)
#     201 # construct operator and offset
#     202 operator, offset = problem_.to_ising()
# --> 204 return self._solve_internal(operator, offset, problem_, problem)
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit_optimization\algorithms\minimum_eigen_optimizer.py:217, in MinimumEigenOptimizer._solve_internal(self, operator, offset, converted_problem, original_problem)
#     214 eigen_result: MinimumEigensolverResult | None = None
#     215 if operator.num_qubits > 0:
#     216     # approximate ground state of operator using min eigen solver
# --> 217     eigen_result = self._min_eigen_solver.compute_minimum_eigenvalue(operator)
#     218     # analyze results
#     219     raw_samples = None
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit_algorithms\minimum_eigensolvers\sampling_vqe.py:238, in SamplingVQE.compute_minimum_eigenvalue(self, operator, aux_operators)
#     233 else:
#     234     # we always want to submit as many estimations per job as possible for minimal
#     235     # overhead on the hardware
#     236     was_updated = _set_default_batchsize(self.optimizer)
# --> 238     optimizer_result = self.optimizer.minimize(
#     239         fun=evaluate_energy,  # type: ignore[arg-type]
#     240         x0=initial_point,
#     241         bounds=bounds,
#     242     )
#     244     # reset to original value
#     245     if was_updated:
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit_algorithms\optimizers\scipy_optimizer.py:162, in SciPyOptimizer.minimize(self, fun, x0, jac, bounds)
#     159     swapped_deprecated_args = True
#     160     self._options["maxfun"] = self._options.pop("maxiter")
# --> 162 raw_result = minimize(
#     163     fun=fun,
#     164     x0=x0,
#     165     method=self._method,
#     166     jac=jac,
#     167     bounds=bounds,
#     168     options=self._options,
#     169     **self._kwargs,
#     170 )
#     171 if swapped_deprecated_args:
#     172     self._options["maxiter"] = self._options.pop("maxfun")
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\scipy\optimize\_minimize.py:744, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#     743 elif meth == 'cobyla':
# --> 744     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     745                            bounds=bounds, **options)
#     746 elif meth == 'cobyqa':
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\scipy\optimize\_cobyla_py.py:35, in synchronized.<locals>.wrapper(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def wrapper(*args, **kwargs):
#      34     with _module_lock:
# ---> 35         return func(*args, **kwargs)
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\scipy\optimize\_cobyla_py.py:278, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, callback, bounds, **unknown_options)
#     275 def _jac(x, *args):
#     276     return None
# --> 278 sf = _prepare_scalar_function(fun, x0, args=args, jac=_jac)
#     280 def calcfc(x, con):
#     281     f = sf.fun(x)
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\scipy\optimize\_optimize.py:291, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     287     bounds = (-np.inf, np.inf)
#     289 # ScalarFunction caches. Reuse of fun(x) during grad
#     290 # calculation reduces overall function evaluations.
# --> 291 sf = ScalarFunction(fun, x0, args, grad, hess,
#     292                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     294 return sf
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\scipy\optimize\_differentiable_functions.py:223, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     220     finite_diff_options["as_linear_operator"] = True
#     222 # Initial function evaluation
# --> 223 self._update_fun()
#     225 # Initial gradient evaluation
#     226 self._wrapped_grad, self._ngev = _wrapper_grad(
#     227     grad,
#     228     fun=self._wrapped_fun,
#     229     args=args,
#     230     finite_diff_options=finite_diff_options
#     231 )
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\scipy\optimize\_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\scipy\optimize\_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit_algorithms\minimum_eigensolvers\sampling_vqe.py:336, in SamplingVQE._get_evaluate_energy.<locals>.evaluate_energy(parameters)
#     334 parameters = np.reshape(parameters, (-1, num_parameters)).tolist()
#     335 job = estimator.run([(ansatz, operator, parameters)])
# --> 336 estimator_result = job.result()[0]
#     337 values = estimator_result.data.evs
#     338 if not values.shape:
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit\primitives\primitive_job.py:65, in PrimitiveJob.result(self)
#      63 if self._result is None:
#      64     self._check_submitted()
# ---> 65     self._result = self._future.result()
#      66 return self._result
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\concurrent\futures\_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit_algorithms\minimum_eigensolvers\diagonal_estimator.py:90, in _DiagonalEstimator._run(self, pubs)
#      89 def _run(self, pubs: list[EstimatorPub]) -> PrimitiveResult[_DiagonalEstimatorResult]:
# ---> 90     return PrimitiveResult([self._run_pub(pub) for pub in pubs])
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit_algorithms\minimum_eigensolvers\diagonal_estimator.py:90, in <listcomp>(.0)
#      89 def _run(self, pubs: list[EstimatorPub]) -> PrimitiveResult[_DiagonalEstimatorResult]:
# ---> 90     return PrimitiveResult([self._run_pub(pub) for pub in pubs])
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit_algorithms\minimum_eigensolvers\diagonal_estimator.py:123, in _DiagonalEstimator._run_pub(self, pub)
#     113         sampler_pubs.append(
#     114             (
#     115                 bound_circuit.measure_all(inplace=False),
#    (...)
#     119             )
#     120         )
#     122 job = self.sampler.run(sampler_pubs)
# --> 123 sampler_pubs_results = job.result()
#     125 for sampler_pub_result, index in zip(sampler_pubs_results, np.ndindex(*bc_circuits.shape)):
#     126     observable = bc_obs[index]
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit\primitives\primitive_job.py:65, in PrimitiveJob.result(self)
#      63 if self._result is None:
#      64     self._check_submitted()
# ---> 65     self._result = self._future.result()
#      66 return self._result
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\concurrent\futures\_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit\primitives\statevector_sampler.py:174, in StatevectorSampler._run(self, pubs)
#     173 def _run(self, pubs: Iterable[SamplerPub]) -> PrimitiveResult[SamplerPubResult]:
# --> 174     results = [self._run_pub(pub) for pub in pubs]
#     175     return PrimitiveResult(results, metadata={"version": 2})
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit\primitives\statevector_sampler.py:174, in <listcomp>(.0)
#     173 def _run(self, pubs: Iterable[SamplerPub]) -> PrimitiveResult[SamplerPubResult]:
# --> 174     results = [self._run_pub(pub) for pub in pubs]
#     175     return PrimitiveResult(results, metadata={"version": 2})
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit\primitives\statevector_sampler.py:187, in StatevectorSampler._run_pub(self, pub)
#     180 arrays = {
#     181     item.creg_name: np.zeros(
#     182         bound_circuits.shape + (pub.shots, item.num_bytes), dtype=np.uint8
#     183     )
#     184     for item in meas_info
#     185 }
#     186 for index, bound_circuit in np.ndenumerate(bound_circuits):
# --> 187     final_state = Statevector(bound_circuit_to_instruction(bound_circuit))
#     188     final_state.seed(self._seed)
#     189     if qargs:
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit\quantum_info\states\statevector.py:101, in Statevector.__init__(self, data, dims)
#      99     self._data = np.ravel(data.data)
#     100 elif isinstance(data, (QuantumCircuit, Instruction)):
# --> 101     self._data = Statevector.from_instruction(data).data
#     102 else:
#     103     raise QiskitError("Invalid input data format for Statevector")
#
# File c:\Users\50360247E\miniconda3\envs\iqm-py310\lib\site-packages\qiskit\quantum_info\states\statevector.py:777, in Statevector.from_instruction(cls, instruction)
#     775     instruction = instruction.to_instruction()
#     776 # Initialize an the statevector in the all |0> state
# --> 777 init = np.zeros(2**instruction.num_qubits, dtype=complex)
#     778 init[0] = 1.0
#     779 vec = Statevector(init, dims=instruction.num_qubits * (2,))
#
# MemoryError: Unable to allocate 64.0 TiB for an array with shape (4398046511104,) and data type complex128

# %% [markdown]
# ## Classical post-processing
# - Recompute SOC for each sampled bitstring; discard or repair any that violate 0 <= SOC <= Emax or the cycle budget.
# - Greedy repair: if SOC dips below 0, flip the latest discharge to idle; if it exceeds Emax, flip the latest charge to idle; then re-check the end-SOC constraint. This keeps changes local.
# - Score candidates with the exact objective, keep the best. Optionally warm-start the quantum solver with the classical MILP optimum.
#
# Quantum calls are commented to keep the notebook runnable even without Qiskit primitives; enable them in an environment that has the providers you want (local simulator, cloud sampler, or annealer connector).
